# %%
import yaml
from yaml.loader import SafeLoader
import time
import datetime
import multiprocessing
from multiprocessing import Pool
from multiprocessing import Process
import threading
import copy

# %%
# filename = 'Milestone1A.yaml'

with open('Milestone1B.yaml') as f:
    data = yaml.load(f, Loader=SafeLoader)
#     print(data)

# %%
def dataLoad(txt, file, inps):
    ct = datetime.datetime.now()
    print(str(ct)+';'+txt+" Executing DataLoad(",inps,")")
    f.write(str(ct)+';'+txt+" Executing DataLoad(",inps,")")

    
    DataTable=pd.read_csv(file)
    NoOfDefects=DataTable.shape[0]-1
    
    ct = datetime.datetime.now()
    print(str(ct)+';'+txt+" Exit")
    f.write(str(ct)+';'+txt+" Exit\n")
    
def timeFunction(txt, val, inps):
    ct = datetime.datetime.now()
    print(str(ct)+';'+txt+" Executing TimeFunction(",inps,")")
    f.write(str(ct)+';'+txt+" Executing TimeFunction("+inps+")\n")
    
    time.sleep(int(val))
    
    ct = datetime.datetime.now()
    print(str(ct)+';'+txt+" Exit")
    f.write(str(ct)+';'+txt+" Exit\n")

# %%
def fun(name, obj, stack):
    
#     print(name, obj)
    
    if(obj['Type']=='Task'):

        str_ = ""
        for it in stack:
            str_ += it+'.'  
            
        ct = datetime.datetime.now()
        print(str(ct)+';' + str_ + name + ' Entry') #TASK entry
        f.write(str(ct)+';' + str_ + name + ' Entry\n')
        
        inps=[]
        for ele in obj['Inputs']:
            inps.append(ele)
        
        temp=""
        for ele in inps[:-1]:
            temp+=str(obj['Inputs'][ele])+','
        temp+=str(obj['Inputs'][inps[-1]])
        
        if(obj['Function']=="DataLoad"):
            dataLoad(str_+name,obj['Inputs']['Filename'],temp)
            
        elif(obj['Function']=="TimeFunction"):         
            timeFunction(str_+name,obj['Inputs']['ExecutionTime'],temp)
            

    if(obj['Type']=='Flow'):
        
        str_ = ""
        for it in stack:
            str_ += it+'.'
            
        ct = datetime.datetime.now()
        print(str(ct)+';' + str_ + name + ' Entry') #FLOW entry        
        f.write(str(ct)+';' + str_ + name + ' Entry\n')
        
        
        
        if(obj['Execution']=="Sequential"):
            for act in obj['Activities']:
                stack_2 = copy.deepcopy(stack)
                stack_2.append(name)
                fun(act, obj['Activities'][act],stack_2)
            
                
        if(obj['Execution']=="Concurrent"):
            
            acts = obj['Activities']
            threads = []
            
            for ele in acts:
                stack_2 = copy.deepcopy(stack)
                stack_2.append(name)
                t = threading.Thread(target=fun, args=(ele, acts[ele], stack_2))
                threads.append(t)
                t.start()
                
            for t in threads:
                t.join()
                

        
        ct = datetime.datetime.now()
        print(str(ct)+';' + str_ + name + ' Exit') #FLOW exit
        f.write(str(ct)+';' + str_ + name + ' Exit\n')

# %%
f = open("Milestone1B_log.txt","w+")
start = list(data.keys())[0]
fun(start, data[start], [])
f.close()
# Out:
# 2022-03-08 14:37:35.513782;M1B_Workflow Entry
# 2022-03-08 14:37:35.514239;M1B_Workflow.TaskA Entry
# 2022-03-08 14:37:35.514413;M1B_Workflow.TaskA Executing TimeFunction( TaskA_Input,1 )
# 2022-03-08 14:37:36.519654;M1B_Workflow.TaskA Exit
# 2022-03-08 14:37:36.520153;M1B_Workflow.FlowA Entry
# 2022-03-08 14:37:36.520713;M1B_Workflow.FlowA.TaskB Entry
# 2022-03-08 14:37:36.521358;M1B_Workflow.FlowA.TaskB Executing TimeFunction( TaskB_Input,14 2022-03-08 14:37:36.522338;M1B_Workflow.FlowA.TaskC Entry
# 2022-03-08 14:37:36.522973;M1B_Workflow.FlowA.TaskC Executing TimeFunction( TaskC_Input,5 )
# 2022-03-08 14:37:36.526711;M1B_Workflow.FlowA.TaskD Entry
# 2022-03-08 14:37:36.527413;M1B_Workflow.FlowA.TaskD Executing TimeFunction( TaskD_Input,5 )
# )
# 2022-03-08 14:37:36.530082;M1B_Workflow.FlowA.FlowB Entry
# 2022-03-08 14:37:36.530642;M1B_Workflow.FlowA.FlowB.TaskE Entry
# 2022-03-08 14:37:36.530755;M1B_Workflow.FlowA.FlowB.TaskE Executing TimeFunction( TaskE_Input,5 )
# 2022-03-08 14:37:36.534138;M1B_Workflow.FlowA.FlowC Entry2022-03-08 14:37:36.535042;M1B_Workflow.FlowA.TaskI Entry
# 2022-03-08 14:37:36.535555;M1B_Workflow.FlowA.TaskI Executing TimeFunction(
# 2022-03-08 14:37:36.535969;M1B_Workflow.FlowA.FlowC.TaskG Entry
# 2022-03-08 14:37:36.536124;M1B_Workflow.FlowA.FlowC.TaskG Executing TimeFunction( TaskI_Input,5 TaskG_Input,2 )
# )
# 2022-03-08 14:37:38.541319;M1B_Workflow.FlowA.FlowC.TaskG Exit
# 2022-03-08 14:37:38.541885;M1B_Workflow.FlowA.FlowC.TaskH Entry
# 2022-03-08 14:37:38.542068;M1B_Workflow.FlowA.FlowC.TaskH Executing TimeFunction( TaskH_Input,2 )
# 2022-03-08 14:37:40.544258;M1B_Workflow.FlowA.FlowC.TaskH Exit
# 2022-03-08 14:37:40.544430;M1B_Workflow.FlowA.FlowC Exit
# 2022-03-08 14:37:41.524891;M1B_Workflow.FlowA.TaskC Exit
# 2022-03-08 14:37:41.532974;M1B_Workflow.FlowA.TaskD Exit2022-03-08 14:37:41.533112;M1B_Workflow.FlowA.FlowB.TaskE Exit
#
# 2022-03-08 14:37:41.533770;M1B_Workflow.FlowA.FlowB.TaskF Entry
# 2022-03-08 14:37:41.533896;M1B_Workflow.FlowA.FlowB.TaskF Executing TimeFunction( TaskF_Input,1 )
# 2022-03-08 14:37:41.540962;M1B_Workflow.FlowA.TaskI Exit
# 2022-03-08 14:37:42.534395;M1B_Workflow.FlowA.FlowB.TaskF Exit
# 2022-03-08 14:37:42.534788;M1B_Workflow.FlowA.FlowB Exit
# 2022-03-08 14:37:50.540910;M1B_Workflow.FlowA.TaskB Exit
# 2022-03-08 14:37:50.542940;M1B_Workflow.FlowA Exit
# 2022-03-08 14:37:50.543327;M1B_Workflow.TaskZ Entry
# 2022-03-08 14:37:50.543471;M1B_Workflow.TaskZ Executing TimeFunction( TaskZ_Input,5 )
# 2022-03-08 14:37:55.544989;M1B_Workflow.TaskZ Exit
# 2022-03-08 14:37:55.545387;M1B_Workflow Exit

# %%
# import time



# if __name__ == '__main__':
# 	p = Process(0)
# 	p.start()
# 	p.join()
# 	p = Process(1)
# # 	p.start()
# # 	p.join()

# %%
# def f(name,val):
#     time.sleep(val)
#     if val == 5:
#         p = Process(target=f, args=('second',val-4))
#         p.start()

#     print('hello', name)

# if __name__ == '__main__':

#     p = Process(target=f, args=('first',5))
#     p.start()
#     p.join()
